# %% [markdown]
# # Este projeto tem como objetivo verificar o comportamento da variável "Tolerância e Inclusão" dos anos de 2016, 2018 e 2020 e sua correlação com outras variáveis presentes nos dados da pesquisa IPS - RJ

# %% [markdown]
# ## Para mais informações
#
# ## Fonte dos dados e links relacionados:
#
# ## https://basedosdados.org/dataset/br-rj-rio-de-janeiro-ipp-ips
#
# ## http://ipsrio.com.br/#aspects%5B%5D=1&aspects%5B%5D=19&aspects%5B%5D=35&aspects%5B%5D=2&map-type=performance&active-cat=1&page=1&tab=map
#
# ## https://www.data.rio/apps/PCRJ::ips-rio-indice-de-progresso-social-da-cidade-do-rio-de-janeiro/explore

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df_ips_rj = pd.read_csv("dimensoes_componentes.csv")

# %%
df_ips_rj.head(5)
# Out:
#     ano regiao_administrativa  ips_geral  \
# 0  2016        Rio De Janeiro      60.77
# 1  2016             Portuaria      45.33
# 2  2016                Centro      57.75
# 3  2016          Rio Comprido      52.43
# 4  2016              Botafogo      87.12
#
#    necessidades_humanas_basicas_nota_dimensao  \
# 0                                       75.84
# 1                                       59.10
# 2                                       62.43
# 3                                       58.97
# 4                                       93.32
#
#    nutricao_cuidados_medicos_basicos  agua_saneamento  moradia  \
# 0                              70.19            83.68    78.16
# 1                              87.63            80.80    67.97
# 2                              59.38            74.18    91.85
# 3                              61.22            84.36    64.78
# 4                              85.15            98.49    99.55
#
#    seguranca_pessoal  fundamentos_bem_estar_nota_dimensao  \
# 0              71.34                                53.28
# 1               0.00                                41.67
# 2              24.31                                52.41
# 3              25.52                                47.19
# 4              90.08                                81.13
#
#    acesso_conhecimento_basico  acesso_informacao  saude_bem_estar  \
# 0                       49.96              50.89            62.03
# 1                       41.34              20.73            64.74
# 2                       55.60              56.00            41.04
# 3                       34.00              42.08            47.84
# 4                       78.47              86.52            81.46
#
#    qualidade_meio_ambiente  oportunidades_nota_dimensao  direitos_individuais  \
# 0                    50.26                        53.20                 61.46
# 1                    39.89                        35.23                 39.35
# 2                    56.99                        58.42                 45.89
# 3                    64.84                        51.14                 66.89
# 4                    78.07                        86.91                 68.19
#
#    liberdades_individuais  tolerancia_inclusao  acesso_educacao_superior
# 0                   54.82                64.14                     32.36
# 1                   61.94                34.18                      5.43
# 2                   87.27                52.24                     48.26
# 3                   50.45                64.74                     22.48
# 4                   85.74                94.30                     99.39

# %% [markdown]
# # 1 Filtragem de ano e região administrativa

# %%
df_ips_rj.ano.unique()
# Out:
# array([2016, 2018, 2020], dtype=int64)

# %%
df_ips_rj.regiao_administrativa.unique()
# Out:
# array(['Rio De Janeiro', 'Portuaria', 'Centro', 'Rio Comprido',
#        'Botafogo', 'Copacabana', 'Lagoa', 'São Cristovão', 'Tijuca',
#        'Vila Isabel', 'Ramos', 'Penha', 'Inhaúma', 'Méier', 'Iraja',
#        'Madureira', 'Jacarepaguá', 'Bangu', 'Campo Grande', 'Santa Cruz',
#        'Ilha Do Governador', 'Anchieta', 'Santa Teresa',
#        'Barra Da Tijuca', 'Pavuna', 'Guaratiba', 'Rocinha', 'Jacarezinho',
#        'Complexo Do Alemão', 'Maré', 'Vigário Geral', 'Realengo',
#        'Cidade De Deus'], dtype=object)

# %% [markdown]
# # 2 Análise exploratória da variável "Tolerância e Inclusão"

# %% [markdown]
# ## 2.1 Montando a tabela com dados do ano de 2020

# %%
ano2020 = df_ips_rj.query("ano==2020") #estamos interessados apenas nos dados referentes ao ano de 2020

# %%
ano2020.head()
# Out:
#      ano regiao_administrativa  ips_geral  \
# 66  2020        Rio De Janeiro      60.79
# 67  2020             Portuaria      42.06
# 68  2020                Centro      55.59
# 69  2020          Rio Comprido      55.50
# 70  2020              Botafogo      85.03
#
#     necessidades_humanas_basicas_nota_dimensao  \
# 66                                       74.13
# 67                                       59.67
# 68                                       59.23
# 69                                       68.27
# 70                                       91.66
#
#     nutricao_cuidados_medicos_basicos  agua_saneamento  moradia  \
# 66                              66.12            83.68    79.57
# 67                              64.32            80.80    71.06
# 68                              56.64            74.18    91.60
# 69                              72.61            84.36    73.29
# 70                              89.92            98.49    99.07
#
#     seguranca_pessoal  fundamentos_bem_estar_nota_dimensao  \
# 66              67.14                                51.63
# 67              22.49                                36.00
# 68              14.52                                50.26
# 69              42.82                                50.81
# 70              79.18                                77.09
#
#     acesso_conhecimento_basico  acesso_informacao  saude_bem_estar  \
# 66                       66.19              50.89            53.08
# 67                       59.51              20.73            19.20
# 68                       61.97              56.00            37.26
# 69                       68.72              42.08            39.33
# 70                       80.70              86.52            78.58
#
#     qualidade_meio_ambiente  oportunidades_nota_dimensao  \
# 66                    36.37                        56.62
# 67                    44.55                        30.52
# 68                    45.82                        57.26
# 69                    53.10                        47.42
# 70                    62.56                        86.32
#
#     direitos_individuais  liberdades_individuais  tolerancia_inclusao  \
# 66                 54.33                   62.72                77.05
# 67                 25.66                   50.76                40.23
# 68                 41.68                   87.28                51.84
# 69                 37.76                   60.82                68.64
# 70                 56.63                   89.80                99.48
#
#     acesso_educacao_superior
# 66                     32.36
# 67                      5.43
# 68                     48.26
# 69                     22.48
# 70                     99.39

# %%
df_ips_2020 = pd.DataFrame(ano2020[["regiao_administrativa", "tolerancia_inclusao"]])
df_ips_2020.head()
# Out:
#    regiao_administrativa  tolerancia_inclusao
# 66        Rio De Janeiro                77.05
# 67             Portuaria                40.23
# 68                Centro                51.84
# 69          Rio Comprido                68.64
# 70              Botafogo                99.48

# %%
df_ips_2020 = df_ips_2020.rename(columns={"regiao_administrativa": "Região", "tolerancia_inclusao" : "Tolerância e inclusão"})

# %%
df_ips_2020.head()
# Out:
#             Região  Tolerância e inclusão
# 66  Rio De Janeiro                  77.05
# 67       Portuaria                  40.23
# 68          Centro                  51.84
# 69    Rio Comprido                  68.64
# 70        Botafogo                  99.48

# %%
df_ips_2020 = df_ips_2020.reset_index(drop = True)

df_ips_2020.head()
# Out:
#            Região  Tolerância e inclusão
# 0  Rio De Janeiro                  77.05
# 1       Portuaria                  40.23
# 2          Centro                  51.84
# 3    Rio Comprido                  68.64
# 4        Botafogo                  99.48

# %%
df_ips_2020 = df_ips_2020.drop(0) #iremos retirar os dados do IPS geral da cidade do Rio de Janeiro
                                   #no momento é preciso somente utilizar os dados das regiões administrativas

# %%
df_ips_2020 = df_ips_2020.reset_index(drop = True)
df_ips_2020
# Out:
#                 Região  Tolerância e inclusão
# 0            Portuaria                  40.23
# 1               Centro                  51.84
# 2         Rio Comprido                  68.64
# 3             Botafogo                  99.48
# 4           Copacabana                  98.53
# 5                Lagoa                  98.57
# 6        São Cristovão                  62.40
# 7               Tijuca                  95.88
# 8          Vila Isabel                  92.14
# 9                Ramos                  76.76
# 10               Penha                  79.57
# 11             Inhaúma                  76.47
# 12               Méier                  84.63
# 13               Iraja                  84.04
# 14           Madureira                  74.38
# 15         Jacarepaguá                  79.79
# 16               Bangu                  70.19
# 17        Campo Grande                  79.22
# 18          Santa Cruz                  71.03
# 19  Ilha Do Governador                  83.26
# 20            Anchieta                  68.30
# 21        Santa Teresa                  69.94
# 22     Barra Da Tijuca                  82.94
# 23              Pavuna                  55.39
# 24           Guaratiba                  45.24
# 25             Rocinha                  64.04
# 26         Jacarezinho                  71.29
# 27  Complexo Do Alemão                  63.52
# 28                Maré                  61.57
# 29       Vigário Geral                  70.56
# 30            Realengo                  68.86
# 31      Cidade De Deus                  68.20

# %% [markdown]
# # 2.1.1 Verificando o comportamento da variável

# %%
df_ips_2020.describe()
# Out:
#        Tolerância e inclusão
# count              32.000000
# mean               73.653125
# std                14.621055
# min                40.230000
# 25%                67.160000
# 50%                71.160000
# 75%                83.020000
# max                99.480000

# %%
n = df_ips_2020.shape[0]
n
# Out:
# 32

# %%
k = 1 + (10/3) * np.log10(n)

# %%
k = int(k.round(0))
k
# Out:
# 6

# %%
frequencia_ = pd.value_counts(pd.cut(x = df_ips_2020["Tolerância e inclusão"], bins = 6, include_lowest = True), 
            sort = False
               )

print(frequencia_)
print("A soma é", frequencia_.sum())
# Out:
# (40.17, 50.105]     2
# (50.105, 59.98]     2
# (59.98, 69.855]     8
# (69.855, 79.73]    10
# (79.73, 89.605]     5
# (89.605, 99.48]     5
# Name: Tolerância e inclusão, dtype: int64
# A soma é 32

# %%
percentual_ = pd.value_counts(pd.cut(x = df_ips_2020["Tolerância e inclusão"], bins = 6, include_lowest = True), 
            sort = False, normalize = True
               )*100

print(percentual_)
print("A soma é", percentual_.sum())
# Out:
# (40.17, 50.105]     6.250
# (50.105, 59.98]     6.250
# (59.98, 69.855]    25.000
# (69.855, 79.73]    31.250
# (79.73, 89.605]    15.625
# (89.605, 99.48]    15.625
# Name: Tolerância e inclusão, dtype: float64
# A soma é 100.0

# %% [markdown]
# # 2.1.2 Classificando os dados e montando a tabela de frequências

# %%
intervalo_2020 = [40.17, 50.10, 59.98, 69.85, 79.73, 89.60, 99.48]
classificacao_2020 = ["Ruim", "Mediano", "Bom", "Muito bom", "Ótimo", "Excelente"]

# %%
freq_2020 = pd.value_counts(pd.cut(x = df_ips_2020["Tolerância e inclusão"], 
            bins = intervalo_2020, labels = classificacao_2020, include_lowest = True), ascending = True)

print(freq_2020)
print("A soma é", freq_2020.sum())
# Out:
# Ruim          2
# Mediano       2
# Ótimo         5
# Excelente     5
# Bom           8
# Muito bom    10
# Name: Tolerância e inclusão, dtype: int64
# A soma é 32

# %%
freq_2020_df = pd.DataFrame(pd.value_counts(pd.cut(x = df_ips_2020["Tolerância e inclusão"], 
            bins = intervalo_2020, labels = classificacao_2020, include_lowest = True), ascending = True))

freq_2020_df = freq_2020_df.rename(columns={'Tolerância e inclusão': 'Frequência'})

freq_2020_df
# Out:
#            Frequência
# Ruim                2
# Mediano             2
# Ótimo               5
# Excelente           5
# Bom                 8
# Muito bom          10

# %%
percent_2020_df = pd.DataFrame(pd.value_counts(pd.cut(x = df_ips_2020["Tolerância e inclusão"],
               bins = intervalo_2020, labels = classificacao_2020, include_lowest = True),
               normalize = True)*100)

percent_2020_df = percent_2020_df.rename(columns={"Tolerância e inclusão": "Porcentagem %"})


percent_2020_df
# Out:
#            Porcentagem %
# Muito bom         31.250
# Bom               25.000
# Ótimo             15.625
# Excelente         15.625
# Ruim               6.250
# Mediano            6.250

# %%
freq_prct_2020 = freq_2020_df.join(percent_2020_df)

df_freq_prct_2020 = freq_prct_2020.sort_values(by = ["Porcentagem %"], ascending = False)

df_freq_prct_2020
# Out:
#            Frequência  Porcentagem %
# Muito bom          10         31.250
# Bom                 8         25.000
# Ótimo               5         15.625
# Excelente           5         15.625
# Ruim                2          6.250
# Mediano             2          6.250

# %%
df_freq_prct_2020 = df_freq_prct_2020.rename(index = {
                                "Ruim": 0,
                                "Mediano": 1,
                                 "Bom": 2,
                                 "Muito bom": 3,
                                "Ótimo": 4,
                                "Excelente": 5,
                                 })

df_freq_prct_2020 = df_freq_prct_2020.sort_index()

df_freq_prct_2020
# Out:
#    Frequência  Porcentagem %
# 0           2          6.250
# 1           2          6.250
# 2           8         25.000
# 3          10         31.250
# 4           5         15.625
# 5           5         15.625

# %%
df_freq_prct_2020 = df_freq_prct_2020.rename(index = {
                                 0: "Ruim",
                                1: "Mediano",
                                2: "Bom",
                                3:"Muito bom",
                                4: "Ótimo",
                                5:"Excelente",
                                 })

df_freq_prct_2020 = df_freq_prct_2020.reset_index()

df_freq_prct_2020
# Out:
#        index  Frequência  Porcentagem %
# 0       Ruim           2          6.250
# 1    Mediano           2          6.250
# 2        Bom           8         25.000
# 3  Muito bom          10         31.250
# 4      Ótimo           5         15.625
# 5  Excelente           5         15.625

# %%
df_freq_prct_2020 = df_freq_prct_2020 = df_freq_prct_2020.rename(index = {
                                0: "40.17 |- 50.10",
                                1: "50.10 |- 59.98",
                                2: "59.98 |- 69.85",
                                3: "69.85 |- 79.73",
                                4: "79.73 |- 89.60",
                                5: "89.60 |- 99.48",
                                 })

df_freq_prct_2020 = df_freq_prct_2020.rename(columns = {"index" : "Classificação"})

df_freq_prct_2020
# Out:
#                Classificação  Frequência  Porcentagem %
# 40.17 |- 50.10          Ruim           2          6.250
# 50.10 |- 59.98       Mediano           2          6.250
# 59.98 |- 69.85           Bom           8         25.000
# 69.85 |- 79.73     Muito bom          10         31.250
# 79.73 |- 89.60         Ótimo           5         15.625
# 89.60 |- 99.48     Excelente           5         15.625

# %%
ax = df_freq_prct_2020['Frequência'].plot.bar(width = 1, color = 'blue', alpha = 0.2, figsize=(10, 6))
ax
# Out:
# <AxesSubplot:>

# %%
df_ips_2020.head()
# Out:
#          Região  Tolerância e inclusão
# 0     Portuaria                  40.23
# 1        Centro                  51.84
# 2  Rio Comprido                  68.64
# 3      Botafogo                  99.48
# 4    Copacabana                  98.53

# %% [markdown]
# ## Aqui utilizaremos o parâmetro "retbins" para descobrirmos a avaliação de todas a regiões administrativas de acordo com os intervalos rotulados pelas labels e em seguida criaremos uma lista com a classificação retornada que posteriormente será adicionada ao DataFrame que classificará todas as regiões

# %%
avaliacao = pd.value_counts(pd.cut( x = df_ips_2020["Tolerância e inclusão"], 
            bins = intervalo_2020, retbins = True, labels = classificacao_2020, include_lowest = True))

print(avaliacao)
# Out:
# [40.17, 50.1, 59.98, 69.85, 79.73, 89.6, 99.48]                                                                                                                                                                                                                                   1
# [Ruim, Mediano, Bom, Excelente, Excelente, Excelente, Bom, Excelente, Excelente, Muito bom, Muito bom, Muito bom, Ótimo, Ótimo, Muito bom, Ótimo, Muito bom, Muito bom, Muito bom, Ótimo, Bom, Muito bom, Ótimo, Mediano, Ruim, Bom, Muito bom, Bom, Bom, Muito bom, Bom, Bom]    1
# dtype: int64

# %%
rating =  ["Ruim", "Mediano", "Bom", "Excelente", 
          "Excelente", "Excelente", "Bom", "Excelente", 
          "Excelente", "Muito bom", "Muito bom", "Muito bom", 
          "Ótimo", "Ótimo", "Muito bom", "Ótimo", 
          "Muito bom", "Muito bom", "Muito bom", "Ótimo", 
          "Bom", "Muito bom", "Ótimo", "Mediano",
          "Ruim", "Bom", "Muito bom", "Bom",
          "Bom", "Muito bom", "Bom", "Bom"]

rating = pd.DataFrame(rating)

rating.head()
# Out:
#            0
# 0       Ruim
# 1    Mediano
# 2        Bom
# 3  Excelente
# 4  Excelente

# %%
df_ips_2020["Classificação"] = rating

df_ips_2020
# Out:
#                 Região  Tolerância e inclusão Classificação
# 0            Portuaria                  40.23          Ruim
# 1               Centro                  51.84       Mediano
# 2         Rio Comprido                  68.64           Bom
# 3             Botafogo                  99.48     Excelente
# 4           Copacabana                  98.53     Excelente
# 5                Lagoa                  98.57     Excelente
# 6        São Cristovão                  62.40           Bom
# 7               Tijuca                  95.88     Excelente
# 8          Vila Isabel                  92.14     Excelente
# 9                Ramos                  76.76     Muito bom
# 10               Penha                  79.57     Muito bom
# 11             Inhaúma                  76.47     Muito bom
# 12               Méier                  84.63         Ótimo
# 13               Iraja                  84.04         Ótimo
# 14           Madureira                  74.38     Muito bom
# 15         Jacarepaguá                  79.79         Ótimo
# 16               Bangu                  70.19     Muito bom
# 17        Campo Grande                  79.22     Muito bom
# 18          Santa Cruz                  71.03     Muito bom
# 19  Ilha Do Governador                  83.26         Ótimo
# 20            Anchieta                  68.30           Bom
# 21        Santa Teresa                  69.94     Muito bom
# 22     Barra Da Tijuca                  82.94         Ótimo
# 23              Pavuna                  55.39       Mediano
# 24           Guaratiba                  45.24          Ruim
# 25             Rocinha                  64.04           Bom
# 26         Jacarezinho                  71.29     Muito bom
# 27  Complexo Do Alemão                  63.52           Bom
# 28                Maré                  61.57           Bom
# 29       Vigário Geral                  70.56     Muito bom
# 30            Realengo                  68.86           Bom
# 31      Cidade De Deus                  68.20           Bom

# %% [markdown]
# # Rankeando do maior para o menor e resetando o Index

# %%
df_ips_2020 = df_ips_2020.sort_values(by=["Tolerância e inclusão"], ascending = False)
df_ips_2020 = df_ips_2020.reset_index()
df_ips_2020
# Out:
#     index              Região  Tolerância e inclusão Classificação
# 0       3            Botafogo                  99.48     Excelente
# 1       5               Lagoa                  98.57     Excelente
# 2       4          Copacabana                  98.53     Excelente
# 3       7              Tijuca                  95.88     Excelente
# 4       8         Vila Isabel                  92.14     Excelente
# 5      12               Méier                  84.63         Ótimo
# 6      13               Iraja                  84.04         Ótimo
# 7      19  Ilha Do Governador                  83.26         Ótimo
# 8      22     Barra Da Tijuca                  82.94         Ótimo
# 9      15         Jacarepaguá                  79.79         Ótimo
# 10     10               Penha                  79.57     Muito bom
# 11     17        Campo Grande                  79.22     Muito bom
# 12      9               Ramos                  76.76     Muito bom
# 13     11             Inhaúma                  76.47     Muito bom
# 14     14           Madureira                  74.38     Muito bom
# 15     26         Jacarezinho                  71.29     Muito bom
# 16     18          Santa Cruz                  71.03     Muito bom
# 17     29       Vigário Geral                  70.56     Muito bom
# 18     16               Bangu                  70.19     Muito bom
# 19     21        Santa Teresa                  69.94     Muito bom
# 20     30            Realengo                  68.86           Bom
# 21      2        Rio Comprido                  68.64           Bom
# 22     20            Anchieta                  68.30           Bom
# 23     31      Cidade De Deus                  68.20           Bom
# 24     25             Rocinha                  64.04           Bom
# 25     27  Complexo Do Alemão                  63.52           Bom
# 26      6       São Cristovão                  62.40           Bom
# 27     28                Maré                  61.57           Bom
# 28     23              Pavuna                  55.39       Mediano
# 29      1              Centro                  51.84       Mediano
# 30     24           Guaratiba                  45.24          Ruim
# 31      0           Portuaria                  40.23          Ruim

# %%
df_ips_2020 = df_ips_2020.drop(columns=["index"])
# Out:
#                 Região  Tolerância e inclusão Classificação
# 0             Botafogo                  99.48     Excelente
# 1                Lagoa                  98.57     Excelente
# 2           Copacabana                  98.53     Excelente
# 3               Tijuca                  95.88     Excelente
# 4          Vila Isabel                  92.14     Excelente
# 5                Méier                  84.63         Ótimo
# 6                Iraja                  84.04         Ótimo
# 7   Ilha Do Governador                  83.26         Ótimo
# 8      Barra Da Tijuca                  82.94         Ótimo
# 9          Jacarepaguá                  79.79         Ótimo
# 10               Penha                  79.57     Muito bom
# 11        Campo Grande                  79.22     Muito bom
# 12               Ramos                  76.76     Muito bom
# 13             Inhaúma                  76.47     Muito bom
# 14           Madureira                  74.38     Muito bom
# 15         Jacarezinho                  71.29     Muito bom
# 16          Santa Cruz                  71.03     Muito bom
# 17       Vigário Geral                  70.56     Muito bom
# 18               Bangu                  70.19     Muito bom
# 19        Santa Teresa                  69.94     Muito bom
# 20            Realengo                  68.86           Bom
# 21        Rio Comprido                  68.64           Bom
# 22            Anchieta                  68.30           Bom
# 23      Cidade De Deus                  68.20           Bom
# 24             Rocinha                  64.04           Bom
# 25  Complexo Do Alemão                  63.52           Bom
# 26       São Cristovão                  62.40           Bom
# 27                Maré                  61.57           Bom
# 28              Pavuna                  55.39       Mediano
# 29              Centro                  51.84       Mediano
# 30           Guaratiba                  45.24          Ruim
# 31           Portuaria                  40.23          Ruim

# %%
df_ips_2020.index = df_ips_2020.index + 1
df_ips_2020
# Out:
#                 Região  Tolerância e inclusão Classificação
# 1             Botafogo                  99.48     Excelente
# 2                Lagoa                  98.57     Excelente
# 3           Copacabana                  98.53     Excelente
# 4               Tijuca                  95.88     Excelente
# 5          Vila Isabel                  92.14     Excelente
# 6                Méier                  84.63         Ótimo
# 7                Iraja                  84.04         Ótimo
# 8   Ilha Do Governador                  83.26         Ótimo
# 9      Barra Da Tijuca                  82.94         Ótimo
# 10         Jacarepaguá                  79.79         Ótimo
# 11               Penha                  79.57     Muito bom
# 12        Campo Grande                  79.22     Muito bom
# 13               Ramos                  76.76     Muito bom
# 14             Inhaúma                  76.47     Muito bom
# 15           Madureira                  74.38     Muito bom
# 16         Jacarezinho                  71.29     Muito bom
# 17          Santa Cruz                  71.03     Muito bom
# 18       Vigário Geral                  70.56     Muito bom
# 19               Bangu                  70.19     Muito bom
# 20        Santa Teresa                  69.94     Muito bom
# 21            Realengo                  68.86           Bom
# 22        Rio Comprido                  68.64           Bom
# 23            Anchieta                  68.30           Bom
# 24      Cidade De Deus                  68.20           Bom
# 25             Rocinha                  64.04           Bom
# 26  Complexo Do Alemão                  63.52           Bom
# 27       São Cristovão                  62.40           Bom
# 28                Maré                  61.57           Bom
# 29              Pavuna                  55.39       Mediano
# 30              Centro                  51.84       Mediano
# 31           Guaratiba                  45.24          Ruim
# 32           Portuaria                  40.23          Ruim

# %%
ax = sns.distplot(df_ips_2020["Tolerância e inclusão"])

ax
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Tolerância e inclusão', ylabel='Density'>

# %%
df_ips_2020["Tolerância e inclusão"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_ips_2020["Tolerância e inclusão"].describe()
# Out:
# count    32.000000
# mean     73.653125
# std      14.621055
# min      40.230000
# 25%      67.160000
# 50%      71.160000
# 75%      83.020000
# max      99.480000
# Name: Tolerância e inclusão, dtype: float64

# %%
df_ips_2020["Tolerância e inclusão"].median()
# Out:
# 71.16

# %%
bx = sns.boxplot(df_ips_2020["Tolerância e inclusão"])
bx
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tolerância e inclusão'>

# %% [markdown]
# # Visualização

# %% [markdown]
# ## Ranking de tolerância e inclusão por região administrativa da cidade do Rio de Janeiro do ano de 2020

# %%
df_ips_2020
# Out:
#                 Região  Tolerância e inclusão Classificação
# 1             Botafogo                  99.48     Excelente
# 2                Lagoa                  98.57     Excelente
# 3           Copacabana                  98.53     Excelente
# 4               Tijuca                  95.88     Excelente
# 5          Vila Isabel                  92.14     Excelente
# 6                Méier                  84.63         Ótimo
# 7                Iraja                  84.04         Ótimo
# 8   Ilha Do Governador                  83.26         Ótimo
# 9      Barra Da Tijuca                  82.94         Ótimo
# 10         Jacarepaguá                  79.79         Ótimo
# 11               Penha                  79.57     Muito bom
# 12        Campo Grande                  79.22     Muito bom
# 13               Ramos                  76.76     Muito bom
# 14             Inhaúma                  76.47     Muito bom
# 15           Madureira                  74.38     Muito bom
# 16         Jacarezinho                  71.29     Muito bom
# 17          Santa Cruz                  71.03     Muito bom
# 18       Vigário Geral                  70.56     Muito bom
# 19               Bangu                  70.19     Muito bom
# 20        Santa Teresa                  69.94     Muito bom
# 21            Realengo                  68.86           Bom
# 22        Rio Comprido                  68.64           Bom
# 23            Anchieta                  68.30           Bom
# 24      Cidade De Deus                  68.20           Bom
# 25             Rocinha                  64.04           Bom
# 26  Complexo Do Alemão                  63.52           Bom
# 27       São Cristovão                  62.40           Bom
# 28                Maré                  61.57           Bom
# 29              Pavuna                  55.39       Mediano
# 30              Centro                  51.84       Mediano
# 31           Guaratiba                  45.24          Ruim
# 32           Portuaria                  40.23          Ruim

# %%
df_ips_2020.describe()
# Out:
#        Tolerância e inclusão
# count              32.000000
# mean               73.653125
# std                14.621055
# min                40.230000
# 25%                67.160000
# 50%                71.160000
# 75%                83.020000
# max                99.480000

# %% [markdown]
# ## Histograma

# %%
df_ips_2020["Tolerância e inclusão"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ax = sns.distplot(df_ips_2020["Tolerância e inclusão"])

ax
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Tolerância e inclusão', ylabel='Density'>

# %% [markdown]
# ## Boxplot

# %%
bx = sns.boxplot(df_ips_2020["Tolerância e inclusão"])
bx
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tolerância e inclusão'>

# %% [markdown]
# ## Tabela de frequências

# %%
df_freq_prct_2020
# Out:
#                Classificação  Frequência  Porcentagem %
# 40.17 |- 50.10          Ruim           2          6.250
# 50.10 |- 59.98       Mediano           2          6.250
# 59.98 |- 69.85           Bom           8         25.000
# 69.85 |- 79.73     Muito bom          10         31.250
# 79.73 |- 89.60         Ótimo           5         15.625
# 89.60 |- 99.48     Excelente           5         15.625

# %%
ax = df_freq_prct_2020["Frequência"].plot.bar(width = 1, color = 'red', alpha = 0.2, figsize=(10, 10))
ax.set_xticklabels(df_freq_prct_2020["Classificação"])
ax
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Verificando a correlação

# %%
dfrj.head()
# Out:
#     ano regiao_administrativa  ips_geral  \
# 0  2016        Rio De Janeiro      60.77
# 1  2016             Portuaria      45.33
# 2  2016                Centro      57.75
# 3  2016          Rio Comprido      52.43
# 4  2016              Botafogo      87.12
#
#    necessidades_humanas_basicas_nota_dimensao  \
# 0                                       75.84
# 1                                       59.10
# 2                                       62.43
# 3                                       58.97
# 4                                       93.32
#
#    nutricao_cuidados_medicos_basicos  agua_saneamento  moradia  \
# 0                              70.19            83.68    78.16
# 1                              87.63            80.80    67.97
# 2                              59.38            74.18    91.85
# 3                              61.22            84.36    64.78
# 4                              85.15            98.49    99.55
#
#    seguranca_pessoal  fundamentos_bem_estar_nota_dimensao  \
# 0              71.34                                53.28
# 1               0.00                                41.67
# 2              24.31                                52.41
# 3              25.52                                47.19
# 4              90.08                                81.13
#
#    acesso_conhecimento_basico  acesso_informacao  saude_bem_estar  \
# 0                       49.96              50.89            62.03
# 1                       41.34              20.73            64.74
# 2                       55.60              56.00            41.04
# 3                       34.00              42.08            47.84
# 4                       78.47              86.52            81.46
#
#    qualidade_meio_ambiente  oportunidades_nota_dimensao  direitos_individuais  \
# 0                    50.26                        53.20                 61.46
# 1                    39.89                        35.23                 39.35
# 2                    56.99                        58.42                 45.89
# 3                    64.84                        51.14                 66.89
# 4                    78.07                        86.91                 68.19
#
#    liberdades_individuais  tolerancia_inclusao  acesso_educacao_superior
# 0                   54.82                64.14                     32.36
# 1                   61.94                34.18                      5.43
# 2                   87.27                52.24                     48.26
# 3                   50.45                64.74                     22.48
# 4                   85.74                94.30                     99.39

# %%
df_correl = dfrj.query("ano == 2016")

df_correl
# Out:
#      ano regiao_administrativa  ips_geral  \
# 0   2016        Rio De Janeiro      60.77
# 1   2016             Portuaria      45.33
# 2   2016                Centro      57.75
# 3   2016          Rio Comprido      52.43
# 4   2016              Botafogo      87.12
# 5   2016            Copacabana      82.93
# 6   2016                 Lagoa      84.94
# 7   2016         São Cristovão      50.72
# 8   2016                Tijuca      78.13
# 9   2016           Vila Isabel      74.12
# 10  2016                 Ramos      57.91
# 11  2016                 Penha      60.28
# 12  2016               Inhaúma      60.84
# 13  2016                 Méier      67.05
# 14  2016                 Iraja      61.94
# 15  2016             Madureira      54.12
# 16  2016           Jacarepaguá      60.74
# 17  2016                 Bangu      54.47
# 18  2016          Campo Grande      58.64
# 19  2016            Santa Cruz      47.84
# 20  2016    Ilha Do Governador      65.01
# 21  2016              Anchieta      57.09
# 22  2016          Santa Teresa      60.52
# 23  2016       Barra Da Tijuca      71.03
# 24  2016                Pavuna      41.10
# 25  2016             Guaratiba      45.27
# 26  2016               Rocinha      44.78
# 27  2016           Jacarezinho      43.82
# 28  2016    Complexo Do Alemão      40.51
# 29  2016                  Maré      50.53
# 30  2016         Vigário Geral      53.31
# 31  2016              Realengo      54.41
# 32  2016        Cidade De Deus      45.44
#
#     necessidades_humanas_basicas_nota_dimensao  \
# 0                                        75.84
# 1                                        59.10
# 2                                        62.43
# 3                                        58.97
# 4                                        93.32
# 5                                        94.58
# 6                                        91.71
# 7                                        67.85
# 8                                        87.86
# 9                                        85.18
# 10                                       72.14
# 11                                       81.02
# 12                                       72.90
# 13                                       79.37
# 14                                       78.16
# 15                                       69.17
# 16                                       73.40
# 17                                       74.70
# 18                                       75.89
# 19                                       64.79
# 20                                       85.65
# 21                                       71.28
# 22                                       68.91
# 23                                       75.16
# 24                                       58.44
# 25                                       53.70
# 26                                       57.07
# 27                                       56.45
# 28                                       61.82
# 29                                       72.96
# 30                                       75.11
# 31                                       72.51
# 32                                       66.42
#
#     nutricao_cuidados_medicos_basicos  agua_saneamento  moradia  \
# 0                               70.19            83.68    78.16
# 1                               87.63            80.80    67.97
# 2                               59.38            74.18    91.85
# 3                               61.22            84.36    64.78
# 4                               85.15            98.49    99.55
# 5                               86.04            99.32    96.54
# 6                               79.24            98.86    96.71
# 7                               70.05            86.36    67.64
# 8                               82.48            84.62    95.15
# 9                               72.45            94.21    86.67
# 10                              54.91            94.92    68.66
# 11                              71.56            97.56    81.70
# 12                              70.68            92.05    82.90
# 13                              67.59            91.26    87.36
# 14                              68.35            97.73    88.04
# 15                              66.97            89.36    82.32
# 16                              70.92            68.78    73.40
# 17                              72.20            89.96    74.80
# 18                              67.08            78.76    76.50
# 19                              64.72            71.21    65.82
# 20                              84.09            89.27    84.51
# 21                              71.92            86.42    77.00
# 22                              62.18            84.64    78.42
# 23                              79.81            50.75    85.31
# 24                              58.83            87.31    60.31
# 25                              68.28            17.54    58.74
# 26                              30.76            78.11    38.83
# 27                              46.46            85.73    21.89
# 28                              57.01            92.98    18.42
# 29                              70.14            82.18    68.87
# 30                              68.70            88.64    71.41
# 31                              63.65            87.40    80.64
# 32                              32.51            93.43    65.34
#
#     seguranca_pessoal  fundamentos_bem_estar_nota_dimensao  \
# 0               71.34                                53.28
# 1                0.00                                41.67
# 2               24.31                                52.41
# 3               25.52                                47.19
# 4               90.08                                81.13
# 5               96.42                                78.09
# 6               92.02                                82.97
# 7               47.34                                42.29
# 8               89.18                                67.13
# 9               87.40                                67.28
# 10              70.06                                46.73
# 11              73.27                                50.29
# 12              45.95                                45.11
# 13              71.28                                55.56
# 14              58.54                                44.77
# 15              38.03                                48.81
# 16              80.48                                55.69
# 17              61.85                                38.85
# 18              81.20                                51.04
# 19              57.42                                40.21
# 20              84.75                                51.77
# 21              49.78                                47.22
# 22              50.39                                63.92
# 23              84.77                                72.19
# 24              27.30                                28.77
# 25              70.22                                44.73
# 26              80.60                                46.71
# 27              71.72                                31.32
# 28              78.88                                29.28
# 29              70.67                                44.11
# 30              71.66                                41.91
# 31              58.34                                47.40
# 32              74.41                                35.84
#
#     acesso_conhecimento_basico  acesso_informacao  saude_bem_estar  \
# 0                        49.96              50.89            62.03
# 1                        41.34              20.73            64.74
# 2                        55.60              56.00            41.04
# 3                        34.00              42.08            47.84
# 4                        78.47              86.52            81.46
# 5                        80.93              81.95            72.39
# 6                        62.49              89.06            84.58
# 7                        44.50              34.65            31.45
# 8                        56.82              80.32            77.75
# 9                        63.06              74.99            74.41
# 10                       47.17              52.42            39.40
# 11                       47.44              43.90            58.21
# 12                       41.76              45.07            48.96
# 13                       51.58              64.58            55.12
# 14                       60.43              54.65            37.21
# 15                       51.43              45.83            48.43
# 16                       47.51              54.36            73.15
# 17                       44.22              33.54            32.28
# 18                       54.86              40.10            61.26
# 19                       46.19              18.98            59.28
# 20                       55.65              57.87            73.88
# 21                       55.83              36.94            48.87
# 22                       63.57              59.89            66.55
# 23                       58.25              78.51            89.26
# 24                       32.01              26.54            56.54
# 25                       53.93              22.15            57.35
# 26                       29.07              24.13            68.85
# 27                        7.99               0.00            85.97
# 28                        0.00              12.85            74.98
# 29                       24.35              15.34            88.47
# 30                       38.60              36.45            47.37
# 31                       55.35              42.68            52.15
# 32                       36.10              23.50            42.77
#
#     qualidade_meio_ambiente  oportunidades_nota_dimensao  \
# 0                     50.26                        53.20
# 1                     39.89                        35.23
# 2                     56.99                        58.42
# 3                     64.84                        51.14
# 4                     78.07                        86.91
# 5                     77.10                        76.13
# 6                     95.74                        80.15
# 7                     58.57                        42.02
# 8                     53.63                        79.39
# 9                     56.67                        69.88
# 10                    47.94                        54.86
# 11                    51.59                        49.52
# 12                    44.65                        64.52
# 13                    50.97                        66.22
# 14                    26.79                        62.87
# 15                    49.54                        44.37
# 16                    47.74                        53.12
# 17                    45.34                        49.86
# 18                    47.94                        49.00
# 19                    36.41                        38.52
# 20                    19.69                        57.61
# 21                    47.24                        52.78
# 22                    65.66                        48.72
# 23                    62.75                        65.75
# 24                     0.00                        36.08
# 25                    45.48                        37.39
# 26                    47.14                        30.55
# 27                    40.98                        43.68
# 28                    47.26                        30.44
# 29                    48.27                        34.50
# 30                    45.23                        42.91
# 31                    39.39                        43.32
# 32                    40.98                        34.06
#
#     direitos_individuais  liberdades_individuais  tolerancia_inclusao  \
# 0                  61.46                   54.82                64.14
# 1                  39.35                   61.94                34.18
# 2                  45.89                   87.27                52.24
# 3                  66.89                   50.45                64.74
# 4                  68.19                   85.74                94.30
# 5                  64.65                   71.18                85.16
# 6                  54.77                   86.21                98.04
# 7                  64.15                   40.63                46.46
# 8                  71.18                   78.81                88.76
# 9                  58.40                   61.45                86.49
# 10                 81.56                   48.68                64.82
# 11                 66.87                   35.47                72.55
# 12                 87.08                   59.10                81.10
# 13                 67.21                   73.98                75.85
# 14                 67.90                   68.77                76.68
# 15                 59.04                   56.36                37.01
# 16                 52.66                   56.71                69.05
# 17                 71.37                   45.50                68.10
# 18                 59.56                   52.99                64.20
# 19                 67.77                   34.23                45.77
# 20                 52.05                   54.32                80.38
# 21                 71.25                   61.62                61.26
# 22                 39.73                   43.48                77.44
# 23                 39.93                   75.30                80.03
# 24                 58.19                   35.40                39.76
# 25                 65.18                   45.39                33.34
# 26                 43.39                   35.20                41.81
# 27                 84.27                   30.02                58.10
# 28                 45.84                    7.36                68.02
# 29                 53.80                   29.91                52.05
# 30                 67.90                   26.64                64.16
# 31                 63.04                   37.98                51.28
# 32                 54.57                   23.24                53.91
#
#     acesso_educacao_superior
# 0                      32.36
# 1                       5.43
# 2                      48.26
# 3                      22.48
# 4                      99.39
# 5                      83.53
# 6                      81.59
# 7                      16.83
# 8                      78.82
# 9                      73.20
# 10                     24.39
# 11                     23.19
# 12                     30.81
# 13                     47.82
# 14                     38.14
# 15                     25.08
# 16                     34.08
# 17                     14.45
# 18                     19.26
# 19                      6.31
# 20                     43.68
# 21                     17.01
# 22                     34.25
# 23                     67.74
# 24                     10.97
# 25                      5.68
# 26                      1.81
# 27                      2.34
# 28                      0.52
# 29                      2.26
# 30                     12.94
# 31                     20.97
# 32                      4.50

# %%
df_correl = pd.DataFrame(df_correl[["regiao_administrativa", "acesso_informacao", "tolerancia_inclusao", 
                                    "direitos_individuais", "liberdades_individuais"]])

# %%
df_correl.head()
# Out:
#   regiao_administrativa  acesso_informacao  tolerancia_inclusao  \
# 0        Rio De Janeiro              50.89                64.14
# 1             Portuaria              20.73                34.18
# 2                Centro              56.00                52.24
# 3          Rio Comprido              42.08                64.74
# 4              Botafogo              86.52                94.30
#
#    direitos_individuais  liberdades_individuais
# 0                 61.46                   54.82
# 1                 39.35                   61.94
# 2                 45.89                   87.27
# 3                 66.89                   50.45
# 4                 68.19                   85.74

# %%
df_correl = df_correl.drop(0)

# %%
df_correl.head()
# Out:
#   regiao_administrativa  acesso_informacao  tolerancia_inclusao  \
# 1             Portuaria              20.73                34.18
# 2                Centro              56.00                52.24
# 3          Rio Comprido              42.08                64.74
# 4              Botafogo              86.52                94.30
# 5            Copacabana              81.95                85.16
#
#    direitos_individuais  liberdades_individuais
# 1                 39.35                   61.94
# 2                 45.89                   87.27
# 3                 66.89                   50.45
# 4                 68.19                   85.74
# 5                 64.65                   71.18

# %%
df_correl = df_correl.reset_index(drop = True)

df_correl
# Out:
#    regiao_administrativa  acesso_informacao  tolerancia_inclusao
# 0              Portuaria              20.73                34.18
# 1                 Centro              56.00                52.24
# 2           Rio Comprido              42.08                64.74
# 3               Botafogo              86.52                94.30
# 4             Copacabana              81.95                85.16
# 5                  Lagoa              89.06                98.04
# 6          São Cristovão              34.65                46.46
# 7                 Tijuca              80.32                88.76
# 8            Vila Isabel              74.99                86.49
# 9                  Ramos              52.42                64.82
# 10                 Penha              43.90                72.55
# 11               Inhaúma              45.07                81.10
# 12                 Méier              64.58                75.85
# 13                 Iraja              54.65                76.68
# 14             Madureira              45.83                37.01
# 15           Jacarepaguá              54.36                69.05
# 16                 Bangu              33.54                68.10
# 17          Campo Grande              40.10                64.20
# 18            Santa Cruz              18.98                45.77
# 19    Ilha Do Governador              57.87                80.38
# 20              Anchieta              36.94                61.26
# 21          Santa Teresa              59.89                77.44
# 22       Barra Da Tijuca              78.51                80.03
# 23                Pavuna              26.54                39.76
# 24             Guaratiba              22.15                33.34
# 25               Rocinha              24.13                41.81
# 26           Jacarezinho               0.00                58.10
# 27    Complexo Do Alemão              12.85                68.02
# 28                  Maré              15.34                52.05
# 29         Vigário Geral              36.45                64.16
# 30              Realengo              42.68                51.28
# 31        Cidade De Deus              23.50                53.91

# %%
correlation = df_correl.corr()

plot = sns.heatmap(correlation, annot = True, fmt = ".1f", linewidths = 6)f

plot
# Out:
# <AxesSubplot:>

# %%
# ρ = 0,9 a 1 (positivo ou negativo): correlação muito forte;
# ρ = 0,7 a 0,9 (positivo ou negativo): correlação forte;
# ρ = 0,5 a 0,7 (positivo ou negativo): correlação moderada;
# ρ = 0,3 a 0,5 (positivo ou negativo): correlação fraca;
# ρ = 0 a 0,3 (positivo ou negativo): não possui correlação.
